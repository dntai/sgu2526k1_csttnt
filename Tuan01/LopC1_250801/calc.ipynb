# %%
# %run ex2_calc.py
# Out:
# Calculator Basic
# c = 20 + 50 = 70

# %%
a
# Out:
# 20

# %%
b
# Out:
# 50

# %%
# !python ex2_calc.py <calc.txt
# Out:
# Calculator Basic
# Moi ban nhap so a: Moi ban nhap so b: c = 60 + 80 = 140
