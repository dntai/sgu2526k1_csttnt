# %%
# %run ex1_calc.py
# Out:
# Calculator Basic
# c = 20 + 30 = 50

# %%
a, b, c
# Out:
# (20, 30, 50)

# %%
# !python ex1_calc.py <calc.txt
# Out:
# Calculator Basic
# Moi ban nhap so a: Moi ban nhap so b: c = 30 + 60 = 90

# %%
# %%writefile calc.txt
# 100
# 200
# Out:
# Overwriting calc.txt

# %%
# !cat calc.txt
# Out:
# 100
# 200

# %%
# !python ex1_calc.py <calc.txt
# Out:
# Calculator Basic
# Moi ban nhap so a: Moi ban nhap so b: c = 100 + 200 = 300
