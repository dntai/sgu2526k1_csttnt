# %%
# %run ex2_calc.py
# Out:
# Calculator Basic
# c = 10 + 30 = 40

# %%
a
# Out:
# 10

# %%
b
# Out:
# 30

# %%
c
# Out:
# 40

# %%
# !python ex2_calc.py <a.txt
# Out:
# Calculator Basic
# Moi ban nhap so a: Moi ban nhap so b: c = 50 + 100 = 150
