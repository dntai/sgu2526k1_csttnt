# %% [markdown]
# # Giải bài 8 Puzzle

# %%
# %load_ext autoreload
# %autoreload 2

from IPython import display
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%writefile puzzle.inp
# 4 8 1
# 6 3 0
# 2 7 5
# 1 2 3
# 4 5 6
# 7 8 0
# Out:
# Writing puzzle.inp

# %%
# !type puzzle.inp
# Out:
# 4 8 1
# 6 3 0
# 2 7 5
# 1 2 3
# 4 5 6
# 7 8 0

# %%
# %run puzzle.py
# Out:
# ['4 8 1\n', '6 3 0\n', '2 7 5\n', '1 2 3\n', '4 5 6\n', '7 8 0\n']
# [[4, 8, 1], [6, 3, 0], [2, 7, 5]]
# [[1, 2, 3], [4, 5, 6], [7, 8, 0]]
# ----------
# ((4, 8, 1), (6, 3, 0), (2, 7, 5))
# {'key': [[4, 8, 1], [6, 3, 0], [2, 7, 5]], 'pos0': (1, 2), 'parent': None, 'cost': 0}
# ********** Start **********
# 4 8 1
# 6 3 0
# 2 7 5
#
# ---------- YIELD **********
# <generator object State.expand at 0x000002C78C0D6480>
# ********** State **********
# 4 8 0
# 6 3 1
# 2 7 5
#
# ********** State **********
# 4 8 1
# 6 3 5
# 2 7 0
#
# ********** State **********
# 4 8 1
# 6 0 3
# 2 7 5
#
# debug for
# ********** Node **********
# 4 8 0
# 6 3 1
# 2 7 5
#
# ********** Node **********
# 4 8 1
# 6 3 5
# 2 7 0
#
# ********** Node **********
# 4 8 1
# 6 0 3
# 2 7 5
#
# ---------- BFS **********

# %%
curNode = states[State._tokey(goal)]
curNode.pprint('goal')

cnt = 0
while curNode is not None:
    cnt = cnt + 1
    curNode.pprint(f'Step: {cnt}')
    curNode = curNode.parent
    pass
# Out:
# ********** goal **********
# 1 2 3
# 4 5 6
# 7 8 0
#
# ********** Step: 1 **********
# 1 2 3
# 4 5 6
# 7 8 0
#
# ********** Step: 2 **********
# 1 2 3
# 4 5 6
# 7 0 8
#
# ********** Step: 3 **********
# 1 2 3
# 4 0 6
# 7 5 8
#
# ********** Step: 4 **********
# 1 0 3
# 4 2 6
# 7 5 8
#
# ********** Step: 5 **********
# 0 1 3
# 4 2 6
# 7 5 8
#
# ********** Step: 6 **********
# 4 1 3
# 0 2 6
# 7 5 8
#
# ********** Step: 7 **********
# 4 1 3
# 2 0 6
# 7 5 8
#
# ********** Step: 8 **********
# 4 1 3
# 2 6 0
# 7 5 8
#
# ********** Step: 9 **********
# 4 1 3
# 2 6 8
# 7 5 0
#
# ********** Step: 10 **********
# 4 1 3
# 2 6 8
# 7 0 5
#
# ********** Step: 11 **********
# 4 1 3
# 2 6 8
# 0 7 5
#
# ********** Step: 12 **********
# 4 1 3
# 0 6 8
# 2 7 5
#
# ********** Step: 13 **********
# 4 1 3
# 6 0 8
# 2 7 5
#
# ********** Step: 14 **********
# 4 1 3
# 6 8 0
# 2 7 5
#
# ********** Step: 15 **********
# 4 1 0
# 6 8 3
# 2 7 5
#
# ********** Step: 16 **********
# 4 0 1
# 6 8 3
# 2 7 5
#
# ********** Step: 17 **********
# 4 8 1
# 6 0 3
# 2 7 5
#
# ********** Step: 18 **********
# 4 8 1
# 6 3 0
# 2 7 5

# %% [markdown]
# ## Kết thúc

# %%
# !jupyter nbconvert --to html puzzle_main.ipynb
# Out:
# [NbConvertApp] Converting notebook puzzle_main.ipynb to html
# [NbConvertApp] Writing 575183 bytes to puzzle_main.html
