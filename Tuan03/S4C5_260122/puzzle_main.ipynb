# %% [markdown]
# # Giải bài toán 8 puzzle

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %run puzzle.py
# Out:
# ----------  ----------
# 1  2  3
# 4  5  6
# 7  8  0
#
# ----------  ----------
# 1  2  3
# 4  5  6
# 7  0  8
#
# ----------  ----------
# 1  2  3
# 4  0  6
# 7  5  8
#
# ----------  ----------
# 1  0  3
# 4  2  6
# 7  5  8
#
# ----------  ----------
# 0  1  3
# 4  2  6
# 7  5  8
#
# ----------  ----------
# 4  1  3
# 0  2  6
# 7  5  8
#
# ----------  ----------
# 4  1  3
# 2  0  6
# 7  5  8
#
# ----------  ----------
# 4  1  3
# 2  6  0
# 7  5  8
#
# ----------  ----------
# 4  1  3
# 2  6  8
# 7  5  0
#
# ----------  ----------
# 4  1  3
# 2  6  8
# 7  0  5
#
# ----------  ----------
# 4  1  3
# 2  6  8
# 0  7  5
#
# ----------  ----------
# 4  1  3
# 0  6  8
# 2  7  5
#
# ----------  ----------
# 4  1  3
# 6  0  8
# 2  7  5
#
# ----------  ----------
# 4  1  3
# 6  8  0
# 2  7  5
#
# ----------  ----------
# 4  1  0
# 6  8  3
# 2  7  5
#
# ----------  ----------
# 4  0  1
# 6  8  3
# 2  7  5
#
# ----------  ----------
# 4  8  1
# 6  0  3
# 2  7  5
#
# ----------  ----------
# ...

# %%
print(content)
print(start)
# Out:
# ['4 8 1\n', '6 3 0\n', '2 7 5\n', '1 2 3\n', '4 5 6\n', '7 8 0']
# [[4, 8, 1], [6, 3, 0], [2, 7, 5]]

# %%
iterChilds = iter(startNode.expand())
State(next(iterChilds)).pprint('1')
State(next(iterChilds)).pprint('2')
State(next(iterChilds)).pprint('3')
State(next(iterChilds)).pprint('4')
# Out:
# ---------- 1 ----------
# 4  8  0
# 6  3  1
# 2  7  5
# ---------- 2 ----------
# 4  8  1
# 6  3  5
# 2  7  0
# ---------- 3 ----------
# 4  8  1
# 6  0  3
# 2  7  5
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[40], line 5
#       3 State(next(iterChilds)).pprint('2')
#       4 State(next(iterChilds)).pprint('3')
# ----> 5 State(next(iterChilds)).pprint('4')
#
# StopIteration:

# %%
for key in startNode.expand():
    state = State(key)
    state.pprint()
# Out:
# ----------  ----------
# 4  8  0
# 6  3  1
# 2  7  5
# ----------  ----------
# 4  8  1
# 6  3  5
# 2  7  0
# ----------  ----------
# 4  8  1
# 6  0  3
# 2  7  5

# %% [markdown]
# ## Kết thúc
