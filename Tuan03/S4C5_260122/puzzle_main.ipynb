# %% [markdown]
# # Giải bài toán 8 puzzle

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %run puzzle.py
# Out:
# ((4, 8, 1), (6, 3, 0), (2, 7, 5))
# {'key': [[4, 8, 1], [6, 3, 0], [2, 7, 5]], 'pos0': (1, 2), 'parent': None, 'cost': 0}
# ---------- Start ----------
# 4  8  1
# 6  3  0
# 2  7  5
# ---------- Goal ----------
# 1  2  3
# 4  5  6
# 7  8  0

# %%
print(content)
print(start)
# Out:
# ['4 8 1\n', '6 3 0\n', '2 7 5\n', '1 2 3\n', '4 5 6\n', '7 8 0']
# [[4, 8, 1], [6, 3, 0], [2, 7, 5]]

# %%
iterChilds = iter(startNode.expand())
State(next(iterChilds)).pprint()
State(next(iterChilds)).pprint()
# Out:
# ----------  ----------
# 4  8  0
# 6  3  1
# 2  7  5
# ----------  ----------
# 4  8  1
# 6  3  5
# 2  7  0

# %% [markdown]
# ## Kết thúc
