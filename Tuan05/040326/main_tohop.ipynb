# %% [markdown]
# # BÀI TOÁN TỔ HỢP

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%writefile TOHOP.INP
# 3 2
# F
# B
# A
# Out:
# Overwriting TOHOP.INP

# %%
# %run tohop.py - --action test1
# Out:
# ----- DOC FILE -----
# n = 3, k = 2, th = ['F', 'B', 'A']
# Ket qua:
# 3
# F B
# F A
# B A

# %%
# %%writefile TOHOP.INP
# 5 3
# A
# B
# C
# D
# E
# Out:
# Overwriting TOHOP.INP

# %%
# %run tohop.py - --action test1
# Out:
# ----- DOC FILE -----
# n = 5, k = 3, th = ['A', 'B', 'C', 'D', 'E']
# Ket qua:
# 10
# A B C
# A B D
# A B E
# A C D
# A C E
# A D E
# B C D
# B C E
# B D E
# C D E

# %%
# %%writefile TOHOP.INP
# 5 3
# A
# B
# C
# D
# E
# Out:
# Overwriting TOHOP.INP

# %%
# %run tohop.py - --action main
# Out:
# 10
# A B C
# A B D
# A B E
# A C D
# A C E
# A D E
# B C D
# B C E
# B D E
# C D E

# %%
# %%writefile TOHOP.INP
# 3 2
# F
# B
# A
# Out:
# Overwriting TOHOP.INP

# %%
# %run tohop.py - --action main
# Out:
# 3
# F B
# F A
# B A

# %% [markdown]
# ## Kết thúc

# %%
# !jupyter nbconvert --to html main_tohop.ipynb
# Out:
# [NbConvertApp] Converting notebook main_tohop.ipynb to html
# [NbConvertApp] Writing 573588 bytes to main_tohop.html
