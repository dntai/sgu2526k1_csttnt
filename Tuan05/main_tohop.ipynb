# %% [markdown]
# # BÀI TOÁN TỔ HỢP

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%writefile TOPHOP.INP
# 5 3
# A
# B
# C
# D
# E
# Out:
# Overwriting TOPHOP.INP

# %%
# %run tohop.py - --action test1
# Out:
# ----- DOC FILE -----
# n = 5, k = 3, th = ['A', 'B', 'C', 'D', 'E']
# Ket qua:
# 10
# A B C
# A B D
# A B E
# A C D
# A C E
# A D E
# B C D
# B C E
# B D E
# C D E

# %%
# %run tohop.py - --action main --file TOHOP.INP
# Out:
# 10
# A B C
# A B D
# A B E
# A C D
# A C E
# A D E
# B C D
# B C E
# B D E
# C D E

# %%
# %%writefile TOHOP.IN1
# 3 2
# F
# B
# A
# Out:
# Overwriting TOHOP.IN1

# %%
# %run tohop.py - --action main --file TOHOP.IN1
# Out:
# 3
# F B
# F A
# B A

# %% [markdown]
# # Kết thúc
