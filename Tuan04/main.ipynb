# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # GIẢI BÀI TOÁN 8 PUZZLE

# %%
# %run puzzle8.py
# Out:
# start = ((1, 2, 3), (0, 4, 6), (7, 5, 8))
# goal = ((1, 2, 3), (4, 5, 6), (7, 8, 0))
# Start:  {'key': ((1, 2, 3), (0, 4, 6), (7, 5, 8)), 'pos0': (1, 0)}
# Goal:  {'key': ((1, 2, 3), (4, 5, 6), (7, 8, 0)), 'pos0': (2, 2)}

# %%
content
# Out:
# ['1 2 3\n', '- 4 6\n', '7 5 8\n', '1 2 3\n', '4 5 6\n', '7 8 -']

# %%
file_path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 file_path
#
# NameError: name 'file_path' is not defined
