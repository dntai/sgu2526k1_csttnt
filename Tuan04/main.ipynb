# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # GIẢI BÀI TOÁN 8 PUZZLE

# %%
# %run puzzle8.py
# Out:
# start = [[1, 2, 3], [0, 4, 6], [7, 5, 8]]
# goal = [[1, 2, 3], [4, 5, 6], [7, 8, 0]]

# %%
v0 = states[State(goal).tokey()]
v0.print()
v1 = states[v0.tokey()].parent
v1.print()

v2 = states[v1.tokey()].parent
v2.print()

v3 = states[v2.tokey()].parent
v3.print()

v4 = states[v3.tokey()].parent
v4.print()
# Out:
# 1  2  3
# 4  5  6
# 7  8  0
#
# 1  2  3
# 4  5  6
# 7  0  8
#
# 1  2  3
# 4  0  6
# 7  5  8
#
# 1  2  3
# 0  4  6
# 7  5  8
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 13
#      10 v3.print()
#      12 v4 = states[v3.tokey()].parent
# ---> 13 v4.print()
#
# AttributeError: 'NoneType' object has no attribute 'print'

# %%
file_path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 file_path
#
# NameError: name 'file_path' is not defined
