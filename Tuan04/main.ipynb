# %% [markdown]
# # GIẢI BÀI TOÁN 8 PUZZLE

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %run puzzle8.py - --action test2
# Out:
# ---------- THUAT TOAN BFS ----------
# + Doc tap tin...
# ---------- Start Node ----------
# 4  8  1
# 6  3  0
# 2  7  5
#
# ---------- Goal Node ----------
# 1  2  3
# 4  5  6
# 7  8  0
#
# + Thuat toan BFS...
# --> So trang thai da mo: 26227
# --> Do sau toi goal: 17
# --> Do sau cay tim kiem: 18
# --> So buoc di: 18
# --> Liet ke cac buoc di:
# ---------- Buoc 1 ----------
# 4  8  1
# 6  3  0
# 2  7  5
#
# ---------- Buoc 2 ----------
# 4  8  1
# 6  0  3
# 2  7  5
#
# ---------- Buoc 3 ----------
# 4  0  1
# 6  8  3
# 2  7  5
#
# ---------- Buoc 4 ----------
# 4  1  0
# 6  8  3
# 2  7  5
#
# ---------- Buoc 5 ----------
# 4  1  3
# 6  8  0
# 2  7  5
#
# ---------- Buoc 6 ----------
# 4  1  3
# 6  0  8
# 2  7  5
#
# ---------- Buoc 7 ----------
# 4  1  3
# 0  6  8
# 2  7  5
#
# ---------- Buoc 8 ----------
# 4  1  3
# 2  6  8
# 0  7  5
#
# ---------- Buoc 9 ----------
# 4  1  3
# 2  6  8
# 7  0  5
#
# ---------- Buoc 10 ----------
# 4  1  3
# 2  6  8
# 7  5  0
#
# ...

# %%
# %run puzzle8.py - --action test3 --heuristic h1
# Out:
# ---------- THUAT TOAN A* ----------
# + Doc tap tin...
# ---------- Start Node ----------
# 4  8  1
# 6  3  0
# 2  7  5
#
# ---------- Goal Node ----------
# 1  2  3
# 4  5  6
# 7  8  0
#
# + Thuat toan A*...
# --> So trang thai da mo: 1014
# --> Do sau toi goal: 17
# --> Do sau cay tim kiem: 17
# --> So buoc di: 18
# --> Liet ke cac buoc di:
# ---------- Buoc 1 ----------
# 4  8  1
# 6  3  0
# 2  7  5
#
# ---------- Buoc 2 ----------
# 4  8  1
# 6  0  3
# 2  7  5
#
# ---------- Buoc 3 ----------
# 4  8  1
# 0  6  3
# 2  7  5
#
# ---------- Buoc 4 ----------
# 4  8  1
# 2  6  3
# 0  7  5
#
# ---------- Buoc 5 ----------
# 4  8  1
# 2  6  3
# 7  0  5
#
# ---------- Buoc 6 ----------
# 4  8  1
# 2  0  3
# 7  6  5
#
# ---------- Buoc 7 ----------
# 4  0  1
# 2  8  3
# 7  6  5
#
# ---------- Buoc 8 ----------
# 4  1  0
# 2  8  3
# 7  6  5
#
# ---------- Buoc 9 ----------
# 4  1  3
# 2  8  0
# 7  6  5
#
# ---------- Buoc 10 ----------
# 4  1  3
# 2  8  5
# 7  6  0
#
# ...

# %%
# %run puzzle8.py - --action test3 --heuristic h2
# Out:
# ---------- THUAT TOAN A* ----------
# + Doc tap tin...
# ---------- Start Node ----------
# 4  8  1
# 6  3  0
# 2  7  5
#
# ---------- Goal Node ----------
# 1  2  3
# 4  5  6
# 7  8  0
#
# + Thuat toan A*...
# --> So trang thai da mo: 49
# --> Do sau toi goal: 17
# --> Do sau cay tim kiem: 17
# --> So buoc di: 18
# --> Liet ke cac buoc di:
# ---------- Buoc 1 ----------
# 4  8  1
# 6  3  0
# 2  7  5
#
# ---------- Buoc 2 ----------
# 4  8  1
# 6  0  3
# 2  7  5
#
# ---------- Buoc 3 ----------
# 4  0  1
# 6  8  3
# 2  7  5
#
# ---------- Buoc 4 ----------
# 4  1  0
# 6  8  3
# 2  7  5
#
# ---------- Buoc 5 ----------
# 4  1  3
# 6  8  0
# 2  7  5
#
# ---------- Buoc 6 ----------
# 4  1  3
# 6  0  8
# 2  7  5
#
# ---------- Buoc 7 ----------
# 4  1  3
# 0  6  8
# 2  7  5
#
# ---------- Buoc 8 ----------
# 4  1  3
# 2  6  8
# 0  7  5
#
# ---------- Buoc 9 ----------
# 4  1  3
# 2  6  8
# 7  0  5
#
# ---------- Buoc 10 ----------
# 4  1  3
# 2  6  8
# 7  5  0
#
# ...

# %% [markdown]
# ## Kết thúc
