# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %run thongketu.ipynb
# Out:
# ['CA AN KIEN\n', 'HOM NAY LA THU HAI\n']
# ----------
# ----- Line: 0 -----
# line = CA AN KIEN
# Dao:  KIEN AN CA
# Thong ke 1:  {'C': 1, 'A': 2, ' ': 2, 'N': 2, 'K': 1, 'I': 1, 'E': 1}
# Thong ke 2:  {'ca': 1, 'an': 1, 'kien': 1}
# ----- Line: 1 -----
# line = HOM NAY LA THU HAI
# Dao:  HAI THU LA NAY HOM
# Thong ke 1:  {'H': 3, 'O': 1, 'M': 1, ' ': 4, 'N': 1, 'A': 3, 'Y': 1, 'L': 1, 'T': 1, 'U': 1, 'I': 1}
# Thong ke 2:  {'hom': 1, 'nay': 1, 'la': 1, 'thu': 1, 'hai': 1}
