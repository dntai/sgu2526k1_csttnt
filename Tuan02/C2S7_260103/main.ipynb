# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys, io
from contextlib import redirect_stdout

# %%
# %run ptbac2.py

# %%
# %%writefile ptbac2.txt
# 1 2 1
# Out:
# Overwriting ptbac2.txt

# %%
# !cat ptbac2.txt
# Out:
# 1 2 1

# %%
# !python ptbac2.py <ptbac2.txt
# Out:
# 1 2 1
# [1.0, 2.0, 1.0]
# a = 1.0, b = 2.0, c = 1.0
# Phuong trinh 1.0x^2 + 2.0x + 1.0 = 0 co 1 nghiem, x1= -1.0!

# %%
# %%writefile ptbac2.txt
# 1 5 6
# Out:
# Overwriting ptbac2.txt

# %%
# !cat ptbac2.txt
# !python ptbac2.py <ptbac2.txt
# Out:
# 1 5 6
# 1 5 6
# [1.0, 5.0, 6.0]
# a = 1.0, b = 5.0, c = 6.0
# Phuong trinh 1.0x^2 + 5.0x + 6.0 = 0 co 2 nghiem, x1= -3.0 va x2 = -2.0!

# %%
# %run ptbac2.py
# Out:
# 1 2 1
# [1.0, 2.0, 1.0]
# a = 1.0, b = 2.0, c = 1.0
# Phuong trinh 1.0x^2 + 2.0x + 1.0 = 0 co 1 nghiem, x1= -1.0!

# %%
import ptbac2

# %%
ptbac2.giaipt_bac2
# Out:
# <function ptbac2.giaipt_bac2(a, b, c)>
