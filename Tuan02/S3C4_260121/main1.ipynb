# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %run thongketu.ipynb
# Out:
# ['CA AN KIEN CA AN KIEN\n', 'HOM NAY LA THU HAI CA AN KIEN\n']
# ----------
# ----- Line: 0 -----
# line = CA AN KIEN CA AN KIEN
# Dao:  KIEN AN CA KIEN AN CA
# Thong ke 1:  {'C': 2, 'A': 4, ' ': 5, 'N': 4, 'K': 2, 'I': 2, 'E': 2}
# Thong ke 2:  {'ca': 2, 'an': 2, 'kien': 2}
# ----- Line: 1 -----
# line = HOM NAY LA THU HAI CA AN KIEN
# Dao:  KIEN AN CA HAI THU LA NAY HOM
# Thong ke 1:  {'H': 3, 'O': 1, 'M': 1, ' ': 7, 'N': 3, 'A': 5, 'Y': 1, 'L': 1, 'T': 1, 'U': 1, 'I': 2, 'C': 1, 'K': 1, 'E': 1}
# Thong ke 2:  {'hom': 1, 'nay': 1, 'la': 1, 'thu': 1, 'hai': 1, 'ca': 1, 'an': 1, 'kien': 1}

# %%
# !pip install nbformat nbclient
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Error parsing dependencies of pyex: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     black (>=20.) ; extra == 'dev'
#           ~~~~~^
# WARNING: Error parsing dependencies of temporal-cache: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     black (>=20.) ; extra == 'dev'
#           ~~~~~^
