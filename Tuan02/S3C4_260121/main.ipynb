# %% [markdown]
# # Thực hành buổi 02

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Giải PT Bậc 2

# %%
# %%writefile ptbac2.inp
# 1 5 6
# Out:
# Writing ptbac2.inp

# %%
# !type ptbac2.inp
# Out:
# 1 5 6

# %%
# !python ptbac2.py
print(a)
# Out:
# ^C
# 10

# %%
# %run ptbac2.py
print(a)
# Out:
#  1 5 6
# 1 5 6
# 10

# %%
# !python ptbac2.py <ptbac2.inp
# Out:
# a = 1, b = 5, c = 6
# sn = 2, x1 = -3.0, x2=-2.0

# %%
# %%writefile ptbac2.inp
# 1 5 6
# Out:
# Overwriting ptbac2.inp

# %%
# !python ptbac2.py <ptbac2.inp
# Out:
# __name__: __main__
# a = 1, b = 5, c = 6
# pt 1x^2+5x+6=0: 2 nghiem, x1 = -3.00, x2= -2.0

# %%
# %%writefile ptbac2.inp
# 0 5 6
# Out:
# Overwriting ptbac2.inp

# %%
# !python ptbac2.py <ptbac2.inp
# Out:
# a = 0, b = 5, c = 6
# pt 0x^2+5x+6=0: 1 nghiem, x1 = -0.83

# %%
import ptbac2
# Out:
# __name__: ptbac2

# %% [markdown]
# ## Kết thúc

# %%
# !jupyter nbconvert --to html main.ipynb
# Out:
# [NbConvertApp] Converting notebook main.ipynb to html
# [NbConvertApp] Writing 573582 bytes to main.html
