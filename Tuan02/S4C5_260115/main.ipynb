# %% [markdown]
# # Lập trình Python Cơ bản

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Giải phương trình bậc 2

# %%
# %%writefile ptbac2.inp
# 1 5 6
# Out:
# Overwriting ptbac2.inp

# %%
# !echo -----
# !type ptbac2.inp
# !echo -----
# Out:
# -----
# 1 5 6
# -----

# %%
# %run ptbac2.py
# Out:
#  1 2 4
# sn = 0, x1 = None, x2 = None
# Phuong trinh 1x^2 + 2x + 4 = 0: vo nghiem

# %%
# !python ptbac2.py <ptbac2.inp
# Out:
# sn = 2, x1 = -3.0, x2 = -2.0
# Phuong trinh 1x^2 + 5x + 6 = 0: 2 nghiem, x1 = -3.0, x2 = -2.0.

# %%
# %%writefile ptbac2.inp
# 0 0 0
# Out:
# Overwriting ptbac2.inp

# %%
# !python ptbac2.py <ptbac2.inp
# Out:
# sn = -1, x1 = None, x2 = None
# Phuong trinh 0x^2 + 0x + 0 = 0: co vo so nghiem

# %%
# %%writefile ptbac2.inp
# 0 0 5
# Out:
# Overwriting ptbac2.inp

# %%
# !python ptbac2.py <ptbac2.inp
# Out:
# sn = 0, x1 = None, x2 = None
# Phuong trinh 0x^2 + 0x + 5 = 0: vo nghiem

# %%
# %%writefile ptbac2.inp
# 0 6 3
# Out:
# Overwriting ptbac2.inp

# %%
# !python ptbac2.py <ptbac2.inp
# Out:
# sn = 1, x1 = -0.5, x2 = None
# Phuong trinh 0x^2 + 6x + 3 = 0: 1 nghiem, x = -0.5.

# %%
# %%writefile ptbac2.inp
# 1 2 1
# Out:
# Overwriting ptbac2.inp

# %%
# !python ptbac2.py <ptbac2.inp
# Out:
# sn = 1, x1 = -1.0, x2 = None
# Phuong trinh 1x^2 + 2x + 1 = 0: 1 nghiem, x = -1.0.

# %%
# %%writefile ptbac2.inp
# 10 2 5
# Out:
# Overwriting ptbac2.inp

# %%
# !python ptbac2.py <ptbac2.inp
# Out:
# sn = 0, x1 = None, x2 = None
# Phuong trinh 10x^2 + 2x + 5 = 0: vo nghiem

# %% [markdown]
# Co 2 nghiem x1 = 10, x2 = 6

# %%
# %%writefile ptbac2.inp
# 1 -16 60
# Out:
# Overwriting ptbac2.inp

# %%
# !python ptbac2.py <ptbac2.inp
# Out:
# Loading...
# sn = 2, x1 = 6.0, x2 = 10.0
# Phuong trinh 1x^2 + -16x + 60 = 0: 2 nghiem, x1 = 6.0, x2 = 10.0.

# %% [markdown]
# Cach load tap tin python

# %%
# !python ptbac2.py <ptbac2.inp
# Out:
# Loading...ptbac2
# Loading...__main__
# sn = 2, x1 = 6.0, x2 = 10.0
# Phuong trinh 1x^2 + -16x + 60 = 0: 2 nghiem, x1 = 6.0, x2 = 10.0.

# %%
from ptbac2 import GiaiPTBac2

# %% [markdown]
# ## Kết thúc

# %%
# !jupyter nbconvert main.ipynb --to html
# Out:
# [NbConvertApp] Converting notebook main.ipynb to html
# [NbConvertApp] Writing 594384 bytes to main.html
